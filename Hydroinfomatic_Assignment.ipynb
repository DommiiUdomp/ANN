# %% [markdown]
# ---
#
# ## **Assignment: Hydroinformatics Analysis for Thailand**
# **Course:** Hydroinformatics
# **Focus Area:** Thailand
#
# ---
#
# ### **Objective**
# The goal of this assignment is to:
# 1. **Choose a hydrological indicator** relevant to Thailand’s context (e.g., SPI, NDVI, streamflow anomaly, or flood index).
# 2. **Compute and process data** using appropriate methods.
# 3. **Visualize the results** effectively for decision-making.
# 4. **Compare the outcomes** with open-source tools (e.g., Google Earth Engine).
# 5. **Assess the potential benefits** for real-world applications in Thailand.
#
# ---

# %% [markdown]
# ### **Steps**
#
# #### **1. Select an Indicator**
# - Choose one hydrological indicator from the list below, or propose your own (with approval):
#   - **Standardized Precipitation Index (SPI):** Drought analysis.
#   - **Normalized Difference Vegetation Index (NDVI):** Vegetation health.
#   - **Streamflow Anomaly:** Changes in streamflow patterns.
#   - **Flood Inundation Map:** Identifying flood-affected areas.
#   - **Terrestrial Water Storage (TWS):** Monitoring water availability.
#
# **Justify your choice:**
# - Why is this indicator relevant for Thailand?
# - What data sources and methods will you use?
#
# ---
#
# #### **2. Data Collection**
# - Use open-source datasets, such as:
#   - **ERA5-Land:** Climate variables like precipitation.
#   - **MODIS or Landsat:** NDVI or flood mapping.
#   - **GRACE:** Terrestrial water storage.
#   - **Streamflow Data:** Available from local or international sources.
# - Explain your data source(s) and any preprocessing steps.
#
# ---
#
# #### **3. Explain the Methodology**
#    - Describe how indicator is calculated:
#      - The time scale (e.g., monthly, seasonal, or annual).
#      - The classification criteria for indicator:
#    - Explain how data patterns are analyzed to complement Drought/Flood risk mapping.
#    - Mention spatial analysis techniques (e.g., clipping to specific regions, aggregating by provinces, or generating time-averaged maps).
#    - Identify regions with high SPI or heavy rainfall during specific periods.
#    - Note connections to flood events, river discharge data, or historical flooding records.
#
# ---
#
# #### **4. Computation**
# - Write a Python script to compute the chosen indicator. Use libraries like:
#   - **Xarray:** For handling multidimensional datasets.
#   - **Numpy/Pandas:** For numerical computation.
#   - **Google Earth Engine (GEE):** For open-source data access and processing.
#
# ---
#
# #### **5. Visualization**
# - Create clear and insightful visualizations using maps, graphs, and tables to visualize results, such as:
#    - **Maps**: Spatial distribution maps or Interactive maps showing areas at risk.
#    - **Graphs**: Time-series plots for trend analysis for key locations or regions.
#    - **Tables**: SPI classifications by province.
#
# ---
#
# #### **5. Comparison with Open-Source Tools**
# - Compare your computed results with Google Earth Engine or other open-source platforms.
# - Reference results from similar studies (e.g., using Google Earth Engine or published risk maps).
# - Discuss the added value of your approach (e.g., higher spatial resolution, specific regional focus).
#
# ---
#
# #### **6. Application and Benefits**
# Write a short report answering the following:
# - How can this analysis benefit Thailand's water management, agriculture, or Thai organizations?
# - How could this be integrated into real-world decision-support systems?
# - What are the limitations of the chosen method?
# - Suggest areas for improvement, like integrating other indicators.
#
# ---
#
# ### **Deliverables**
# 1. **Findings**: Summarize the main findings and benefits
# 2. **Code**: Submit a Jupyter Notebook or Python script containing your computations and visualizations.
# 3. **Visualizations**: Provide clear graphs/maps and comparisons with open-source outputs.
# 4. **Report**: Submit a 3-5 page document discussing the indicator selection, methods, results, and potential applications.
#
# ---

# %% [markdown]
# ### **Evaluation Criteria**
# - **Indicator Justification**: Relevance and reasoning for indicator selection.
# - **Computation Accuracy**: Correct implementation of methods and handling of data.
# - **Visualization**: Clarity and effectiveness of graphs/maps.
# - **Comparison with Open-Source Tools**: Insightful comparisons and analysis.
# - **Report and Application Discussion**: Practical insights and benifits for Thailand.
#
# ---
